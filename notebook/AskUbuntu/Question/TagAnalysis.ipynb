# %% [markdown]
# ![Python Logo](../../assets/images/python-logo-master-v3-TM.png)
#
# # <center> Exploratory Data Analysis for AskUbuntu Question Data </center>
# ### <center> Shagun Sodhani </center>

# %%
# put in the name of the Stack Exchange Site which you want to analyse.
data_source = "AskUbuntu"
data_type = "Question"
base_url = "http://askubuntu.com/questions/tagged/"

# %% [markdown]
# ## Let us begin

# %% [markdown]
# ### We will import everything in one cell for the sake for reference.

# %%
import pyspark.sql.functions as func
import matplotlib.pyplot as plt
import seaborn as sns
from pyspark.mllib.fpm import FPGrowth
import pandas as pd
from time import time
import operator
# %matplotlib inline
from __future__ import print_function

# %% [markdown]
# ### Now let us load the question data as a dataframe. Since we will be using this data many times, we will cache it in memory.

# %%
start_time = time()
print ("data_source =", data_source)
print ("data_type =", data_type)
question_data_path = "../../data/"+data_source+"/"+data_type
print ("question_data_path =",question_data_path)
question_df = sqlContext.read.load(question_data_path).cache()
print ("Time taken =", time() - start_time, "seconds.")
# Out:
# data_source = AskUbuntu
# data_type = Question
# question_data_path = ../../data/AskUbuntu/Question
# Time taken = 0.212697029114 seconds.

# %%
print("Schema for question dataframe")
question_df.printSchema()
# Out:
# Schema for question dataframe
# root
#  |-- Id: long (nullable = true)
#  |-- AcceptedAnswerId: long (nullable = true)
#  |-- CreationDate: string (nullable = true)
#  |-- Score: long (nullable = true)
#  |-- ViewCount: long (nullable = true)
#  |-- Body: string (nullable = true)
#  |-- OwnerUserId: long (nullable = true)
#  |-- LastEditorUserId: long (nullable = true)
#  |-- LastEditorDisplayName: string (nullable = true)
#  |-- LastEditDate: string (nullable = true)
#  |-- LastActivityDate: string (nullable = true)
#  |-- CommunityOwnedDate: string (nullable = true)
#  |-- ClosedDate: string (nullable = true)
#  |-- Title: string (nullable = true)
#  |-- Tags: string (nullable = true)
#  |-- AnswerCount: long (nullable = true)
#  |-- CommentCount: long (nullable = true)
#  |-- FavoriteCount: long (nullable = true)

# %% [markdown]
# ### We want to play with the tag data.

# %%
question_df.select('Tags').show(10, truncate = False)
# Out:
# +----------------------------------------+
# |Tags                                    |
# +----------------------------------------+
# |<updates><unattended-upgrades>          |
# |<wallpaper><artwork><photography>       |
# |<package-management><uninstall>         |
# |<command-line><package-management>      |
# |<ntp>                                   |
# |<applet><panel><networking>             |
# |<metacity><window-buttons>              |
# |<wine><browser><ie>                     |
# |<thunderbird><google-calendar><calendar>|
# |<firewall>                              |
# +----------------------------------------+
# only showing top 10 rows

# %% [markdown]
# ### We need to clean up this data. Specifically, we want to remove the "<>" signs. We will use the [regex_replace](https://spark.apache.org/docs/1.5.2/api/python/pyspark.sql.html#pyspark.sql.functions.regexp_replace) function.

# %%
question_df.select(func.regexp_replace\
                   (func.regexp_replace('Tags', '><', ','), '<|>', '').alias('Tags')).show(10, truncate = False)
# Out:
# +------------------------------------+
# |Tags                                |
# +------------------------------------+
# |updates,unattended-upgrades         |
# |wallpaper,artwork,photography       |
# |package-management,uninstall        |
# |command-line,package-management     |
# |ntp                                 |
# |applet,panel,networking             |
# |metacity,window-buttons             |
# |wine,browser,ie                     |
# |thunderbird,google-calendar,calendar|
# |firewall                            |
# +------------------------------------+
# only showing top 10 rows

# %% [markdown]
# ### But we do not want just tags. We want other metrics like Score, ViewCount etc as well.

# %%
column_list = ["Score", "ViewCount", "AnswerCount", "CommentCount", "FavoriteCount"]
tags_df = question_df.select("Score", "ViewCount", "AnswerCount", "CommentCount", "FavoriteCount", func.regexp_replace\
                   (func.regexp_replace('Tags', '><', ','), '<|>', '').alias('Tags'))
tags_df.show(10, truncate = False)
# Out:
# +-----+---------+-----------+------------+-------------+------------------------------------+
# |Score|ViewCount|AnswerCount|CommentCount|FavoriteCount|Tags                                |
# +-----+---------+-----------+------------+-------------+------------------------------------+
# |88   |44595    |5          |1           |27           |updates,unattended-upgrades         |
# |16   |641      |1          |2           |2            |wallpaper,artwork,photography       |
# |11   |3571     |3          |1           |2            |package-management,uninstall        |
# |147  |26759    |6          |1           |40           |command-line,package-management     |
# |17   |37191    |3          |1           |10           |ntp                                 |
# |2    |3048     |2          |1           |0            |applet,panel,networking             |
# |9    |1186     |3          |0           |2            |metacity,window-buttons             |
# |12   |5807     |0          |0           |0            |wine,browser,ie                     |
# |6    |969      |4          |0           |1            |thunderbird,google-calendar,calendar|
# |18   |81736    |3          |3           |10           |firewall                            |
# +-----+---------+-----------+------------+-------------+------------------------------------+
# only showing top 10 rows

# %% [markdown]
# ### Now we want to have multiple rows corresponding to each row of *Tags* such that each row has only one *Tag* and all the metrics belonging to the original row. We will use the [split function](https://spark.apache.org/docs/1.5.2/api/python/pyspark.sql.html#pyspark.sql.functions.split) and [explode function](https://spark.apache.org/docs/1.5.2/api/python/pyspark.sql.html#pyspark.sql.functions.explode).

# %%
tag_df = tags_df.select("Score", "ViewCount", "AnswerCount", "CommentCount", "FavoriteCount", func.explode(\
        func.split('Tags', ',')).alias('Tag')).cache()
tag_df.show(10, truncate = False)
# Out:
# +-----+---------+-----------+------------+-------------+-------------------+
# |Score|ViewCount|AnswerCount|CommentCount|FavoriteCount|Tag                |
# +-----+---------+-----------+------------+-------------+-------------------+
# |88   |44595    |5          |1           |27           |updates            |
# |88   |44595    |5          |1           |27           |unattended-upgrades|
# |16   |641      |1          |2           |2            |wallpaper          |
# |16   |641      |1          |2           |2            |artwork            |
# |16   |641      |1          |2           |2            |photography        |
# |11   |3571     |3          |1           |2            |package-management |
# |11   |3571     |3          |1           |2            |uninstall          |
# |147  |26759    |6          |1           |40           |command-line       |
# |147  |26759    |6          |1           |40           |package-management |
# |17   |37191    |3          |1           |10           |ntp                |
# +-----+---------+-----------+------------+-------------+-------------------+
# only showing top 10 rows

# %% [markdown]
# ### Next we [groupBy](https://spark.apache.org/docs/1.5.2/api/python/pyspark.sql.html#pyspark.sql.DataFrame.groupBy) this data using *Tag* as the key and find out the aggregations corresponding to each of the metrics.

# %%
agg_list = ["sum"]*(len(column_list))
aggregation_map = (dict(zip(column_list, agg_list)))
groupded_tag_df = tag_df.groupBy('Tag').agg(aggregation_map)
groupded_tag_df.describe().toPandas()
# Out:
#   summary    sum(AnswerCount)     sum(ViewCount)         sum(Score)  \
# 0   count                3012               3012               3012
# 1    mean   262.5996015936255  626007.1580345286  444.0504648074369
# 2  stddev  1074.8681018802083  2700600.292591697  1762.805850455362
# 3     min                   0                 10                 -5
# 4     max               23289           72136113              46803
#
#    sum(CommentCount)  sum(FavoriteCount)
# 0               3012                3012
# 1  325.5401726427623  140.08333333333334
# 2  1480.240786885741   567.6228558096535
# 3                  0                   0
# 4              38587               14690

# %% [markdown]
# ### Disclaimer - Pandas is used only for visualising the processed data in tabular form as Jupyter notebooks visualise Pandas dataframes very nicely. All the processing is being done by Spark.

# %% [markdown]
# ### Now we want to rank tags by order of their score so that we know which tags result in high scoring questions.

# %%
groupded_tag_df.select('Tag', 'sum(Score)').orderBy('sum(Score)').toPandas()
# Out:
#                           Tag  sum(Score)
# 0                    festival          -5
# 1                         cmd          -5
# 2                        kali          -4
# 3                   backtrack          -2
# 4                          m2          -2
# 5                      pdfsam          -1
# 6                    heimdall          -1
# 7                       iperf          -1
# 8            case-insensitive          -1
# 9                     hexdump          -1
# 10                   coreboot          -1
# 11                      mssql           0
# 12                packetfence           0
# 13                     qgifer           0
# 14                kolourpaint           0
# 15               custom-fonts           0
# 16                  changelog           0
# 17             font-converter           0
# 18                    usb-dac           0
# 19                   xwinwrap           0
# 20               shiny-server           0
# 21                        dia           0
# 22                bluegriffon           0
# 23                     xperia           0
# 24                    mugshot           0
# 25                   hunspell           0
# 26         distributed-system           0
# 27                     libpng           0
# 28                     murmur           0
# 29                     burner           0
# ...                       ...         ...
# 2982                    12.10        7207
# 2983                    sound        7507
# 2984                dual-boot        7609
# 2985                  scripts        7777
# 2986               virtualbox        8143
# 2987                  upgrade        8305
# 2988                 nautilus        8586
# 2989             installation        8698
# 2990                   nvidia        8733
# 2991                      ssh        8769
# 2992                  drivers        9177
# 2993                    11.04        9275
# 2994                    grub2        9284
# 2995            shortcut-keys        9321
# 2996                   kernel        9351
# 2997                 wireless       10045
# 2998                     boot       12937
# 2999                    11.10       13091
# 3000                   server       13496
# 3001                    gnome       13885
# 3002               networking       14887
# 3003    software-installation       15104
# 3004       package-management       15259
# 3005                     bash       15491
# 3006  software-recommendation       16566
# 3007                    14.04       21749
# 3008                      apt       23396
# 3009                    12.04       26246
# 3010                    unity       29093
# 3011             command-line       46803
#
# [3012 rows x 2 columns]

# %% [markdown]
# ### We can repeat this excercise for any of our metric.

# %%
groupded_tag_df.select('Tag', 'sum(ViewCount)').orderBy('sum(ViewCount)').toPandas()
# Out:
#                           Tag  sum(ViewCount)
# 0                      texdoc              10
# 1                    corebird              10
# 2                usb-ethernet              12
# 3                      pdfsam              14
# 4            exceed-on-demand              17
# 5                 low-latency              17
# 6               terminal-plus              20
# 7                  biometrics              20
# 8                         ros              20
# 9                      gjiten              20
# 10              insync-marker              22
# 11         distributed-system              22
# 12                    hexchat              23
# 13                        cfq              23
# 14                        dia              24
# 15                       inxi              27
# 16                kolourpaint              28
# 17                     fitbit              33
# 18                    mythweb              35
# 19                  geoserver              36
# 20                 cowbuilder              37
# 21                     omegat              38
# 22             kde-activities              39
# 23                  broadwell              40
# 24                      lives              40
# 25                    mp3wrap              40
# 26                     fabric              43
# 27                       scsh              44
# 28                    unoconv              44
# 29                    usb-dac              46
# ...                       ...             ...
# 2982                     sudo        11526296
# 2983                   kernel        11605566
# 2984                    12.10        11833265
# 2985                      usb        12340312
# 2986                    mount        12957801
# 2987             partitioning        13364131
# 2988                    gnome        13461808
# 2989              permissions        13591744
# 2990                   nvidia        14130130
# 2991      system-installation        14483901
# 2992                      ssh        14568746
# 2993                dual-boot        16741172
# 2994                     bash        17251048
# 2995  software-recommendation        17864763
# 2996       package-management        18011357
# 2997             installation        18381870
# 2998                    11.10        18445454
# 2999               virtualbox        18457832
# 3000                  drivers        18523417
# 3001                    grub2        20590876
# 3002                 wireless        21131976
# 3003                    unity        24147259
# 3004                     boot        24498276
# 3005                   server        24850781
# 3006               networking        25997856
# 3007                      apt        32535203
# 3008                    14.04        33797555
# 3009    software-installation        36059755
# 3010                    12.04        50178424
# 3011             command-line        72136113
#
# [3012 rows x 2 columns]

# %% [markdown]
# ### Instead of sum, we want to see the average value of these metrics.

# %%
agg_list = ["avg"]*(len(column_list))
aggregation_map = (dict(zip(column_list, agg_list)))
groupded_tag_df = tag_df.groupBy('Tag').agg(aggregation_map)
groupded_tag_df.describe().toPandas()
# Out:
#   summary    avg(AnswerCount)     avg(ViewCount)          avg(Score)  \
# 0   count                3012               3012                3012
# 1    mean   1.261576813100134  2658.697828055242   2.410384949150589
# 2  stddev  0.5133550607662078  3009.932010924707  2.4140642082317814
# 3     min                 0.0               10.0                -2.0
# 4     max                 8.0  32894.43939393939                34.3
#
#     avg(CommentCount)  avg(FavoriteCount)
# 0                3012                3012
# 1   1.425766698023223   0.714533869149954
# 2  0.9902837728225818  0.8302195305978429
# 3                 0.0                 0.0
# 4                16.0                14.0

# %%
groupded_tag_df.select('Tag', 'avg(Score)').orderBy('avg(Score)').toPandas()
# Out:
#                      Tag  avg(Score)
# 0                     m2   -2.000000
# 1                 pdfsam   -1.000000
# 2                hexdump   -1.000000
# 3                    cmd   -1.000000
# 4               festival   -0.833333
# 5               heimdall   -0.500000
# 6                  iperf   -0.500000
# 7               coreboot   -0.500000
# 8       case-insensitive   -0.333333
# 9              backtrack   -0.086957
# 10                  kali   -0.064516
# 11                 mssql    0.000000
# 12           packetfence    0.000000
# 13                qgifer    0.000000
# 14           kolourpaint    0.000000
# 15          custom-fonts    0.000000
# 16             changelog    0.000000
# 17        font-converter    0.000000
# 18               usb-dac    0.000000
# 19              xwinwrap    0.000000
# 20          shiny-server    0.000000
# 21                   dia    0.000000
# 22           bluegriffon    0.000000
# 23                xperia    0.000000
# 24               mugshot    0.000000
# 25              hunspell    0.000000
# 26    distributed-system    0.000000
# 27                libpng    0.000000
# 28                murmur    0.000000
# 29                burner    0.000000
# ...                  ...         ...
# 2982                gzip   12.151515
# 2983             crontab   12.184211
# 2984                epub   12.650000
# 2985              equivs   12.750000
# 2986               vdpau   12.952381
# 2987                 nux   13.500000
# 2988   ubuntu-membership   13.571429
# 2989              ubufox   14.333333
# 2990        sound-editor   14.333333
# 2991       free-software   14.600000
# 2992                chef   14.800000
# 2993                mobi   15.250000
# 2994    powerline-plugin   16.571429
# 2995              zombie   17.187500
# 2996   history-of-ubuntu   17.583333
# 2997            whoopsie   18.277778
# 2998               visio   18.400000
# 2999             audible   18.500000
# 3000          easter-egg   20.500000
# 3001          shellshock   20.625000
# 3002           coreutils   20.636364
# 3003         theoretical   21.000000
# 3004          cd-command   21.000000
# 3005                 bfs   22.000000
# 3006     posix-compliant   22.000000
# 3007           ram-usage   22.900000
# 3008          gnome-open   23.000000
# 3009             nethogs   30.000000
# 3010        time-command   30.000000
# 3011       shopping-lens   34.300000
#
# [3012 rows x 2 columns]

# %%
groupded_tag_df.select('Tag', 'avg(AnswerCount)').orderBy('avg(AnswerCount)').toPandas()
# Out:
#                         Tag  avg(AnswerCount)
# 0                    qgifer          0.000000
# 1             terminal-plus          0.000000
# 2            font-converter          0.000000
# 3                   usb-dac          0.000000
# 4                   crimson          0.000000
# 5                      hive          0.000000
# 6                   symbian          0.000000
# 7                   mugshot          0.000000
# 8           openstack-trove          0.000000
# 9        distributed-system          0.000000
# 10                     hdpi          0.000000
# 11            indicator-syc          0.000000
# 12         display-rotation          0.000000
# 13               cowbuilder          0.000000
# 14               biometrics          0.000000
# 15                   texdoc          0.000000
# 16                   tomoyo          0.000000
# 17         exceed-on-demand          0.000000
# 18                      ros          0.000000
# 19                unclutter          0.000000
# 20                   pdfsam          0.000000
# 21                broadwell          0.000000
# 22                    lives          0.000000
# 23                   caldav          0.000000
# 24                    dahdi          0.000000
# 25                  avprobe          0.000000
# 26       skype-for-business          0.000000
# 27                 ballview          0.000000
# 28                   gnutls          0.000000
# 29                 isolinux          0.000000
# ...                     ...               ...
# 2982                 chmsee          3.000000
# 2983                  neatx          3.000000
# 2984          security-card          3.000000
# 2985          release-notes          3.000000
# 2986        virtual-printer          3.000000
# 2987                hexdump          3.000000
# 2988                 pstree          3.000000
# 2989                    ifs          3.000000
# 2990                 f-spot          3.000000
# 2991           time-command          3.000000
# 2992               appimage          3.000000
# 2993                  cr-48          3.000000
# 2994         microsoft-lync          3.000000
# 2995             web-design          3.200000
# 2996  amazon-mp3-downloader          3.333333
# 2997                  simon          3.333333
# 2998                   mobi          3.500000
# 2999              ascii-art          3.500000
# 3000                  x121e          3.600000
# 3001                freemat          3.666667
# 3002         file-extension          3.750000
# 3003          google-reader          4.000000
# 3004             production          4.000000
# 3005          digital-dairy          4.000000
# 3006           sound-editor          4.333333
# 3007             cd-command          5.000000
# 3008                    aif          5.000000
# 3009             easter-egg          5.166667
# 3010                  visio          5.400000
# 3011             gnome-open          8.000000
#
# [3012 rows x 2 columns]

# %% [markdown]
# ## <center> [Frequent Patterns](http://spark.apache.org/docs/latest/api/python/pyspark.mllib.html#pyspark.mllib.fpm.FPGrowth) </center>

# %% [markdown]
# ### Frequent Pattern - Set of tags which frequently occur together
# ### Support - Measure of how frequently the tag appears in the data

# %% [markdown]
# ### First we need to process our data to make it look like transcational data. We will map each row to array of tags. Each array of tags would define one transaction.

# %%
tags_transaction = tags_df.select(func.split('Tags', ',').alias('Tags')).map(lambda line: line[0]).cache()
for transaction in tags_transaction.take(5):
    print (transaction)
print ("Number of questions =",tags_transaction.count())
# Out:
# [u'updates', u'unattended-upgrades']
# [u'wallpaper', u'artwork', u'photography']
# [u'package-management', u'uninstall']
# [u'command-line', u'package-management']
# [u'ntp']
# Number of questions = 230177

# %%
start_time = time()
model = FPGrowth.train(tags_transaction, minSupport=0.01, numPartitions=10)
result = sorted(model.freqItemsets().collect(), key = lambda a: -1*a[1])
for fi in result[:10]:
    print(fi)
print ("Time taken =", time() - start_time, "seconds.")
# Out:
# FreqItemset(items=[u'14.04'], freq=20795)
# FreqItemset(items=[u'12.04'], freq=17532)
# FreqItemset(items=[u'boot'], freq=11307)
# FreqItemset(items=[u'networking'], freq=10355)
# FreqItemset(items=[u'command-line'], freq=10342)
# FreqItemset(items=[u'dual-boot'], freq=9109)
# FreqItemset(items=[u'drivers'], freq=8427)
# FreqItemset(items=[u'unity'], freq=8351)
# FreqItemset(items=[u'wireless'], freq=8234)
# FreqItemset(items=[u'server'], freq=7629)
# Time taken = 3.52160596848 seconds.
